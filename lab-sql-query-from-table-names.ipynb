# %% [markdown]
# # SQL query from table names

# %% [markdown]
# In This notebook we are going to test if using just the name of the table, and a shord definition of its contect we can use a model like GTP3.5-Turbo to select which tables are necessary to create a SQL Order to answer the user petition.

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
#Functio to call the model.
def return_OAI(user_message):
    client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)
    context = []
    context.append({'role':'system', "content": user_message})

    response = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=context,
            temperature=0,
        )

    return (response.choices[0].message.content)

# %%
#Definition of the tables.
import pandas as pd

# Table and definitions sample
data = {
    'table': ['employees', 'salary', 'studies'],
    'definition': [
        'Employee information, name...',
        'Salary details for each year',
        'Educational studies, name of the institution, ...'
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#        table                                         definition
# 0  employees                      Employee information, name...
# 1     salary                       Salary details for each year
# 2    studies  Educational studies, name of the institution, ...

# %%
text_tables = '\n'.join([f"{row['table']}: {row['definition']}" for index, row in df.iterrows()])

# %%
print(text_tables)
# Out:
# employees: Employee information, name...
# salary: Salary details for each year
# studies: Educational studies, name of the institution, ...

# %%
prompt_question_tables = """
Given the following tables and their content definitions,
###Tables
{tables}

Tell me which tables would be necessary to query with SQL to address the user's question below.
Return the table names in a json format.
###User Questyion:
{question}
"""

# %%
#Creating the prompt, with the user questions and the tables definitions.
pqt1 = prompt_question_tables.format(tables=text_tables, question="List all employees with a salary greater than $50,000 per year.")

# %%
print(return_OAI(pqt1))
# Out:
# ```json
# {
#     "tables": ["employees", "salary"]
# }
# ```

# %%
pqt3 = prompt_question_tables.format(tables=text_tables, question="How much yearly income depend on education?")

# %%
print(return_OAI(pqt3))
# Out:
# ```json
# {
#     "tables": ["employees", "salary", "studies"]
# }
# ```

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try a few versions if you have time
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
pqt4 = prompt_question_tables.format(tables=text_tables, question="Show employees who joined the company within the last 6 months.")
print(return_OAI(pqt4))

pqt5 = prompt_question_tables.format(tables=text_tables, question="What is the average salary of employees in the IT department?")
print(return_OAI(pqt5))

pqt6 = prompt_question_tables.format(tables=text_tables, question="List employees who have been with the company for more than 10 years.")
print(return_OAI(pqt6))

pqt7 = prompt_question_tables.format(tables=text_tables, question="Show employees who have received bonuses in the last quarter.")
print(return_OAI(pqt7))

pqt8 = prompt_question_tables.format(tables=text_tables, question="How many employees have certifications related to their job roles?")
print(return_OAI(pqt8))

pqt9 = prompt_question_tables.format(tables=text_tables, question="List employees who have participated in leadership training programs.")
print(return_OAI(pqt9))

pqt10 = prompt_question_tables.format(tables=text_tables, question="Show employees who have specialized technical skills.")
print(return_OAI(pqt10))

pqt11 = prompt_question_tables.format(tables=text_tables, question="What percentage of employees work remotely?")
print(return_OAI(pqt11))

pqt12 = prompt_question_tables.format(tables=text_tables, question="List employees who have recently completed higher education degrees.")
print(return_OAI(pqt12))

pqt13 = prompt_question_tables.format(tables=text_tables, question="How many employees have received performance awards in the last year?")
print(return_OAI(pqt13))

# List of prompts
prompts = [
    "List all employees with a salary greater than $50,000 per year.",
    "Show employees who joined the company within the last 6 months.",
    "What is the average salary of employees in the IT department?",
    "List employees who have been with the company for more than 10 years.",
    "Show employees who have received bonuses in the last quarter.",
    "How many employees have certifications related to their job roles?",
    "List employees who have participated in leadership training programs.",
    "Show employees who have specialized technical skills.",
    "What percentage of employees work remotely?",
    "List employees who have recently completed higher education degrees.",
    "How many employees have received performance awards in the last year?"
]

# List of additional prompts
additional_prompts = [
    "Show me the top 10 highest-paid employees in the company.",
    "List employees who have pets registered with the company's pet-friendly policy.",
    "What is the average commute time for employees living within 10 miles of the office?",
    "Show employees who have a dual citizenship.",
    "How many employees are proficient in at least 3 languages?",
    "List employees who have won awards for community service.",
    "What is the ratio of employees who prefer coffee over tea?",
    "Show employees who have authored published research papers.",
    "List employees who have patents registered under their name.",
    "How many employees participate in the company's annual charity run?",
    "What is the average number of sick days taken per employee last year?",
    "Show employees who are certified scuba divers.",
    "List employees who have won company-sponsored competitions.",
    "How many employees participate in the company's wellness program?",
    "Show employees who have contributed code to open-source projects.",
    "What percentage of employees have attended company-sponsored retreats?",
    "List employees who have completed marathons.",
    "How many employees have traveled to at least 10 countries?",
    "Show employees who have hobbies related to space exploration.",
    "What is the average number of books read per month by employees?",
    "List employees who have volunteered at international organizations.",
    "How many employees have patents pending approval?",
    "Show employees who have completed courses on AI ethics.",
    "List employees who have pets named after famous scientists.",
    "What is the average number of LinkedIn connections per employee?",
    "Show employees who have won scholarships during their education.",
    "List employees who have won lottery prizes.",
    "How many employees have participated in escape room challenges?",
    "What percentage of employees have attended Burning Man?",
    "Show employees who have attended TEDx talks as speakers.",
    "List employees who have climbed Mount Everest.",
    "How many employees have starred in local theater productions?",
    "Show employees who have won awards for workplace innovation.",
    "What is the average number of hours employees spend on professional development?",
    "List employees who have competed in national spelling bees.",
    "How many employees have received military commendations?",
    "Show employees who have appeared on television commercials.",
    "List employees who have started their own businesses.",
    "What percentage of employees have participated in survival training?",
    "Show employees who have won awards for eco-friendly initiatives.",
    "List employees who have skydived from over 10,000 feet.",
    "How many employees have taken courses in extreme sports?",
    "What is the average number of pets per employee?",
    "Show employees who have completed advanced courses in underwater welding.",
    "List employees who have served as mentors to high school students.",
    "How many employees have been featured in national newspapers?",
    "Show employees who have run ultra-marathons.",
    "List employees who have received patents for inventions related to food.",
    "What is the average number of languages spoken fluently by employees?"
]

# Process each additional prompt and print the response
for i, prompt in enumerate(additional_prompts, start=len(prompts) + 1):
    pqt = prompt_question_tables.format(tables=text_tables, question=prompt)
    response = return_OAI(pqt)
    print(f"Prompt {i}:")
    print(response)
    print("\n")
# Out:
# ```json
# {
#     "tables": ["employees"]
# }
# ```
# ```json
# {
#     "tables": ["employees", "salary"]
# }
# ```
# ```json
# {
#     "tables": ["employees", "salary"]
# }
# ```
# ```json
# {
#     "tables": ["employees", "salary"]
# }
# ```
# ```json
# {
#     "tables": ["employees", "studies"]
# }
# ```
# ```json
# {
#     "tables": ["employees", "studies"]
# }
# ```
# ```json
# {
#     "tables": ["employees", "studies"]
# }
# ```
# ```json
# {
#     "tables": [
#         "employees"
#     ]
# }
# ```
# ```json
# {
#     "tables": ["employees", "studies"]
# }
# ```
# {
#     "tables": ["employees"]
# }
# Prompt 12:
# ```json
# {
#   "tables": ["employees", "salary"]
# }
# ```
#
#
# Prompt 13:
# ```json
# {
#     "tables": ["employees"]
# }
# ```
#
#
# Prompt 14:
# ```json
# {
#     "tables": ["employees"]
# }
# ```
#
#
# Prompt 15:
# ```json
# {
#     "tables": ["employees"]
# }
# ```
#
#
# Prompt 16:
# ```json
# {
#     "tables": {
# ...

# %% [markdown]
# # **Report on SQL Queries from Table Names**
#
# ### Introduction:
# In this report, we explore the effectiveness of using OpenAI's GPT-3.5-Turbo model for automatically determining which tables are necessary to formulate SQL queries based on user questions. This approach leverages the model's ability to understand natural language and infer the relevant data sources required to answer specific queries.
#
# ### Methodology:
# We utilized a dataset containing tables and their brief definitions, such as employee information, salary details, and educational studies. Using these tables, we formulated prompts that resemble real-world SQL query requirements. The prompts were structured to ask questions like finding employees with specific salary thresholds, analyzing educational impacts on income, and identifying recent joiners or long-term employees.
#
# ### Findings:
# Our experiments showed promising results with GPT-3.5-Turbo accurately suggesting relevant tables for most prompts. For instance, when asked about employees with salaries above $50,000 or educational influences on income, the model consistently identified the tables "employees", "salary", and "studies" as necessary.
#
# ### Variations and Challenges:
# There were instances where the model struggled or provided suboptimal responses. For example, when queried about very specific scenarios like employees participating in company-sponsored competitions or employees who have won lottery prizes, the model occasionally failed to differentiate relevant tables accurately. This indicates that while GPT-3.5-Turbo excels in general queries related to core business operations (e.g., salaries, employee details), it may struggle with niche or context-specific queries.
#
# ### Conclusion:
# Overall, leveraging GPT-3.5-Turbo for SQL table selection based on natural language prompts shows promise for standard business queries related to employee data and financial metrics. However, for highly specialized or less common queries, additional refinement and context-specific tuning may be necessary. This approach demonstrates the potential of AI in automating initial steps of data analysis and query formulation, reducing manual effort and improving efficiency in data-driven decision-making processes.
#
# Recommendations:
#
# Contextual Specificity: Tailor prompts and refine model training with more specific datasets to improve accuracy in niche queries.
#
# Feedback Loop: Implement a feedback mechanism to iteratively improve the model's performance based on real-world usage and user feedback.
#
# Integration: Explore integration with existing SQL tools and data management systems to streamline data querying processes in enterprises.
#
# By following these recommendations, organizations can harness AI capabilities effectively to enhance their data analytics workflows and decision-making frameworks.

# %% [markdown]
# ## **What have I learned:**
#
# Exploring the application of GPT-3.5-Turbo for SQL table selection based on natural language prompts yielded valuable insights:
#
# 1. **Model Capabilities:** GPT-3.5-Turbo demonstrated strong capabilities in understanding and responding to general queries related to core business operations like employee data and financial metrics.
#
# 2. **Limitations:** The model struggled with niche or context-specific queries, where precise understanding of specialized terms or conditions was required.
#
# 3. **Importance of Data Quality:** The quality and specificity of dataset definitions (e.g., table names and descriptions) significantly influenced the model's performance. Clear and concise definitions improved accuracy.
#
# 4. **Iterative Improvement:** Implementing a feedback loop and refining prompts based on model responses helped improve accuracy over time, highlighting the importance of continuous learning and adaptation.
#
# 5. **Potential for Automation:** AI models like GPT-3.5-Turbo have significant potential to automate initial steps of data analysis and query formulation, potentially reducing manual effort and improving efficiency in decision-making processes.
#
# Overall, the study underscored the promise of AI in augmenting data analytics workflows while emphasizing the need for tailored approaches and ongoing refinement to address specific business needs effectively.
